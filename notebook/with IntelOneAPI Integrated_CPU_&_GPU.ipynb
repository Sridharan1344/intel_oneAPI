# %%
pip install scikit-learn-intelex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn-intelex in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (2024.1.0)
# Requirement already satisfied: daal4py==2024.1.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn-intelex) (2024.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn-intelex) (1.4.1.post1)
# Requirement already satisfied: daal==2024.1.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from daal4py==2024.1.0->scikit-learn-intelex) (2024.1.0)
# Requirement already satisfied: numpy>=1.19 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from daal4py==2024.1.0->scikit-learn-intelex) (1.26.4)
# Requirement already satisfied: tbb==2021.* in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from daal==2024.1.0->daal4py==2024.1.0->scikit-learn-intelex) (2021.11.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (3.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (24.0)

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from scikit-learn) (3.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load dataset from CSV
csv = 'data.csv'
df = pd.read_csv(csv)

# %% [markdown]
# GETTING THE INFORMATION OF THE DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CPU_Clock_Speed       1000 non-null   float64
#  1   CPU_Cores             1000 non-null   int64
#  2   CPU_Cache_Size        1000 non-null   int64
#  3   CPU_TDP               1000 non-null   int64
#  4   CPU_Brand_Model       1000 non-null   object
#  5   GPU_Clock_Speed       1000 non-null   int64
#  6   GPU_Cores             1000 non-null   int64
#  7   GPU_Memory_Size       1000 non-null   int64
#  8   GPU_Memory_Bandwidth  1000 non-null   int64
#  9   GPU_Brand_Model       1000 non-null   object
#  10  Performance_Metric    1000 non-null   int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 86.1+ KB

# %% [markdown]
# CHECK FOR NULL VALUES

# %%
df.isnull().sum()
# Out:
# CPU_Clock_Speed         0
# CPU_Cores               0
# CPU_Cache_Size          0
# CPU_TDP                 0
# CPU_Brand_Model         0
# GPU_Clock_Speed         0
# GPU_Cores               0
# GPU_Memory_Size         0
# GPU_Memory_Bandwidth    0
# GPU_Brand_Model         0
# Performance_Metric      0
# dtype: int64

# %%
df
# Out:
#      CPU_Clock_Speed  CPU_Cores  CPU_Cache_Size  CPU_TDP CPU_Brand_Model  \
# 0                3.8          7              15      103     AMD Ryzen 5
# 1                2.7         12              28      144   Intel Core i7
# 2                3.8          7              10      100   Intel Core i7
# 3                3.2         10               9       88     AMD Ryzen 5
# 4                2.2          8              16      123   Intel Core i7
# ..               ...        ...             ...      ...             ...
# 995              3.0          2              25      120   Intel Core i5
# 996              2.0         12               7      101   Intel Core i5
# 997              4.1          3              32       91     AMD Ryzen 7
# 998              2.1         11              28      149   Intel Core i3
# 999              3.7          7               5       49   Intel Core i7
#
#      GPU_Clock_Speed  GPU_Cores  GPU_Memory_Size  GPU_Memory_Bandwidth  \
# 0               1522        481                3                   368
# 1               1622        131                7                   148
# 2               1380        439                7                   325
# 3               1010        377                6                   208
# 4               1489        458                8                   137
# ..               ...        ...              ...                   ...
# 995             1656        479                6                   227
# 996             1244        180                7                   257
# 997             1242        349               10                   147
# 998             1877        287                4                   155
# 999             1246        408                7                   193
#
#        GPU_Brand_Model  Performance_Metric
# 0      NVIDIA GTX 1050                1822
# 1      NVIDIA GTX 1060                 955
# 2    AMD Radeon RX 570                1059
# 3      NVIDIA GTX 1650                1918
# 4    AMD Radeon RX 580                1329
# ..                 ...                 ...
# 995  AMD Radeon RX 570                 701
# 996    NVIDIA GTX 1660                1607
# 997  AMD Radeon RX 580                1958
# 998    NVIDIA GTX 1660                1765
# 999    NVIDIA GTX 1050                1761
#
# [1000 rows x 11 columns]

# %%
# Convert categorical variables to one-hot encoding
df_encoded = pd.get_dummies(df, columns=['CPU_Brand_Model', 'GPU_Brand_Model'])

# %%
# User input for features
user_input = {
    'CPU_Clock_Speed': float(input("Enter CPU Clock Speed (GHz): ")),
    'CPU_Cores': int(input("Enter number of CPU Cores: ")),
    'CPU_Cache_Size': int(input("Enter CPU Cache Size (MB): ")),
    'CPU_TDP': int(input("Enter CPU TDP (Watts): ")),
    'GPU_Clock_Speed': float(input("Enter GPU Clock Speed (MHz): ")),
    'GPU_Cores': int(input("Enter number of GPU Cores: ")),
    'GPU_Memory_Size': int(input("Enter GPU Memory Size (GB): ")),
    'GPU_Memory_Bandwidth': int(input("Enter GPU Memory Bandwidth (bits): "))
}
# Out:
# Enter CPU Clock Speed (GHz):  4.4
# Enter number of CPU Cores:  12
# Enter CPU Cache Size (MB):  30
# Enter CPU TDP (Watts):  165
# Enter GPU Clock Speed (MHz):  1822
# Enter number of GPU Cores:  822
# Enter GPU Memory Size (GB):  12
# Enter GPU Memory Bandwidth (bits):  612

# %% [markdown]
# Convert user input to DataFrame

# %%
# Convert user input to DataFrame
user_df = pd.DataFrame([user_input])

# %% [markdown]
# Set Features and target

# %%
# Features and target
features = ['CPU_Clock_Speed', 'CPU_Cores', 'CPU_Cache_Size', 'CPU_TDP',
            'GPU_Clock_Speed', 'GPU_Cores', 'GPU_Memory_Size', 'GPU_Memory_Bandwidth']

# %%
from sklearn.model_selection import train_test_split
x = df[features]
y = df['Performance_Metric']

# %%
x
# Out:
#      CPU_Clock_Speed  CPU_Cores  CPU_Cache_Size  CPU_TDP  GPU_Clock_Speed  \
# 0                3.8          7              15      103             1522
# 1                2.7         12              28      144             1622
# 2                3.8          7              10      100             1380
# 3                3.2         10               9       88             1010
# 4                2.2          8              16      123             1489
# ..               ...        ...             ...      ...              ...
# 995              3.0          2              25      120             1656
# 996              2.0         12               7      101             1244
# 997              4.1          3              32       91             1242
# 998              2.1         11              28      149             1877
# 999              3.7          7               5       49             1246
#
#      GPU_Cores  GPU_Memory_Size  GPU_Memory_Bandwidth
# 0          481                3                   368
# 1          131                7                   148
# 2          439                7                   325
# 3          377                6                   208
# 4          458                8                   137
# ..         ...              ...                   ...
# 995        479                6                   227
# 996        180                7                   257
# 997        349               10                   147
# 998        287                4                   155
# 999        408                7                   193
#
# [1000 rows x 8 columns]

# %%
y
# Out:
# 0      1822
# 1       955
# 2      1059
# 3      1918
# 4      1329
#        ...
# 995     701
# 996    1607
# 997    1958
# 998    1765
# 999    1761
# Name: Performance_Metric, Length: 1000, dtype: int64

# %% [markdown]
# SPLIT THE TRAIN AND TEST DATA SET

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_test
# Out:
#      CPU_Clock_Speed  CPU_Cores  CPU_Cache_Size  CPU_TDP  GPU_Clock_Speed  \
# 993              3.6         12              26      130             1357
# 859              3.0          4              11       49             1484
# 298              3.0          7              17       53             1928
# 553              2.9         10              25      121             1328
# 672              2.9          3              24       71             1184
# ..               ...        ...             ...      ...              ...
# 679              2.3          7               5      126             1700
# 722              2.4          4               7       58             1891
# 215              2.5          5              25      102             1788
# 653              2.0          5              12      138             1757
# 150              2.2          2              14      144             1312
#
#      GPU_Cores  GPU_Memory_Size  GPU_Memory_Bandwidth
# 993        302                7                   299
# 859        178                7                   101
# 298        320                7                   354
# 553        410                6                   104
# 672        472                2                   217
# ..         ...              ...                   ...
# 679        450                8                   358
# 722        440                9                   356
# 215        174                3                   350
# 653        294                3                   125
# 150        223                9                   198
#
# [200 rows x 8 columns]

# %%
train_data=x_train.join(y_train)
train_data
# Out:
#      CPU_Clock_Speed  CPU_Cores  CPU_Cache_Size  CPU_TDP  GPU_Clock_Speed  \
# 687              3.2          2              25      115             1318
# 500              2.8          3              15      113             1138
# 332              4.2         10              14      116             1737
# 979              3.4          3              13       96             1367
# 817              2.3          7              32      107             1579
# ..               ...        ...             ...      ...              ...
# 835              4.1         10              13      135             1316
# 192              4.4          9               9      135             1122
# 629              2.6          6              32       71             1970
# 559              4.1          9               4      120             1515
# 684              2.8         11              30      122             1722
#
#      GPU_Cores  GPU_Memory_Size  GPU_Memory_Bandwidth  Performance_Metric
# 687        183                6                   197                1948
# 500        468                3                   271                1010
# 332        429                6                   289                 728
# 979        165                8                   145                 789
# 817        199                9                   182                1409
# ..         ...              ...                   ...                 ...
# 835        175               12                   341                 572
# 192        429                9                   128                1433
# 629        206               10                   122                 901
# 559        490               11                   101                 950
# 684        284               10                   226                1638
#
# [800 rows x 9 columns]

# %%
y_test = df['Performance_Metric'].values

# %%
y_test
# Out:
# array([1822,  955, 1059, 1918, 1329,  795, 1399,  759, 1658, 1712, 1790,
#        1305, 1084, 1136, 1597, 1107,  897,  774,  975, 1947, 1245, 1979,
#        1234,  978, 1361, 1460, 1933,  988, 1672, 1619,  511, 1392, 1879,
#        1023, 1704,  729,  519, 1368,  838, 1990, 1914, 1733,  841, 1218,
#        1563,  595, 1955, 1055, 1106,  932,  950,  578, 1698,  997, 1943,
#        1687, 1662,  806, 1676,  707,  986, 1406,  892, 1626,  851, 1632,
#        1159,  647,  595,  826,  974,  898, 1821, 1685, 1041, 1842, 1993,
#         977, 1471, 1736, 1580,  541, 1654,  578, 1568, 1833, 1708, 1037,
#        1654, 1780, 1837,  619, 1985, 1923, 1348,  931,  516,  507, 1217,
#         713, 1041, 1246,  763, 1679,  941,  718, 1030, 1147, 1752, 1721,
#        1761, 1385,  567, 1147, 1342, 1587, 1788, 1982, 1820, 1181, 1012,
#         917, 1254,  585,  923, 1399, 1791, 1972, 1694, 1285,  695, 1361,
#         659, 1389,  957, 1615, 1646, 1613, 1310,  801, 1034, 1031, 1233,
#         615,  824, 1127,  820, 1858, 1369,  992, 1898,  609, 1205, 1328,
#        1733,  847, 1843,  628, 1921, 1131,  869, 1474, 1968,  702,  818,
#        1109,  637, 1466, 1245, 1358,  873,  882,  549, 1210,  829,  667,
#         706, 1001, 1556, 1092,  621, 1196, 1805, 1301, 1113,  634, 1524,
#        1190, 1373,  723, 1732, 1642, 1433,  736, 1293, 1334, 1757,  929,
#         887, 1263,  943,  542, 1541,  806, 1740, 1368, 1655,  937, 1968,
#        1961, 1467,  861,  927, 1081,  879, 1205, 1292,  832, 1060,  615,
#        1290, 1932, 1008, 1141, 1117, 1286, 1031, 1093, 1584, 1815, 1942,
#        1923, 1276, 1469, 1306, 1392, 1464,  532, 1463, 1398, 1048, 1065,
#        1575,  735,  730, 1622, 1487, 1821, 1689, 1445, 1567, 1247,  850,
#         904, 1612,  699, 1875,  905, 1481,  896, 1809,  573, 1197,  660,
#        1117, 1268,  985, 1629, 1200, 1023,  583,  794,  506, 1616, 1826,
#        1531, 1129, 1638, 1661, 1820, 1948, 1666, 1273, 1867,  954, 1761,
#         774, 1832,  934, 1743, 1337, 1001, 1053, 1315, 1613,  837, 1511,
#         502, 1722, 1477, 1661,  507, 1390, 1360, 1548,  685,  884, 1045,
#        1341, 1889, 1919, 1219,  908, 1686,  780, 1543,  915,  534, 1423,
#         878, 1546, 1544, 1596,  893,  925,  894, 1749, 1872, 1537, 1348,
#        1041,  753,  517,  573,  978, 1091, 1989,  883, 1719, 1136,  561,
#        1873, 1856, 1399, 1927, 1069,  893,  895, 1409, 1903, 1866, 1414,
#         618, 1418,  708, 1561,  726, 1965, 1606, 1260, 1460,  588, 1182,
#         753, 1311,  951,  855, 1088,  793, 1742, 1748, 1418, 1592, 1357,
#        1588, 1742, 1798, 1463,  621, 1189, 1650,  837, 1924, 1277, 1672,
#        1859,  981,  750,  921,  597, 1768,  786,  540,  673, 1991, 1419,
#        1830,  796, 1747,  647, 1970, 1744, 1133, 1663,  789, 1980, 1143,
#         519,  685, 1754, 1409, 1171,  898,  627,  801, 1348,  905, 1421,
#        1285, 1620,  742, 1588, 1183,  825,  559, 1597, 1383,  517,  572,
#        1282, 1632, 1440, 1751, 1480, 1403,  764,  822, 1869, 1156, 1728,
#        1835, 1319,  800, 1681, 1279, 1699, 1803, 1367, 1634, 1752, 1111,
#         899, 1949,  829, 1140,  579, 1962, 1003, 1696,  586,  788, 1088,
#         878,  789, 1814, 1824, 1442, 1159, 1794,  632,  685,  782, 1952,
#        1309, 1066,  666,  974,  725, 1060,  779, 1303, 1438, 1256, 1696,
#         826, 1024,  974,  785, 1697,  611, 1024, 1355, 1167, 1623,  682,
#        1651, 1276, 1976,  859, 1169,  852, 1562,  903, 1219, 1954,  543,
#        1347,  799, 1656, 1932, 1544,  648, 1357, 1696,  551, 1875, 1050,
#        1874, 1570, 1642, 1536, 1984,  917,  705, 1276,  933, 1299, 1222,
#        1876,  908, 1510, 1158,  618, 1019,  691, 1689,  519,  986, 1923,
#        1149, 1161, 1416,  771, 1432,  986,  750, 1868,  533, 1997,  548,
#         868, 1399,  805,  712, 1846, 1587, 1864, 1211,  838, 1012, 1489,
#         656, 1911, 1229, 1818, 1052,  962, 1882,  504, 1665,  989, 1850,
#         789, 1981,  896,  554, 1387, 1926,  900, 1070, 1510,  747,  609,
#         743, 1997, 1336,  632, 1870,  701, 1607, 1958, 1765, 1761])

# %%
train_data.hist(figsize=(8,8))
# Out:
# array([[<Axes: title={'center': 'CPU_Clock_Speed'}>,
#         <Axes: title={'center': 'CPU_Cores'}>,
#         <Axes: title={'center': 'CPU_Cache_Size'}>],
#        [<Axes: title={'center': 'CPU_TDP'}>,
#         <Axes: title={'center': 'GPU_Clock_Speed'}>,
#         <Axes: title={'center': 'GPU_Cores'}>],
#        [<Axes: title={'center': 'GPU_Memory_Size'}>,
#         <Axes: title={'center': 'GPU_Memory_Bandwidth'}>,
#         <Axes: title={'center': 'Performance_Metric'}>]], dtype=object)

# %%
train_data.corr()
# Out:
#                       CPU_Clock_Speed  CPU_Cores  CPU_Cache_Size   CPU_TDP  \
# CPU_Clock_Speed              1.000000   0.030933        0.026289  0.018280
# CPU_Cores                    0.030933   1.000000       -0.024582  0.018433
# CPU_Cache_Size               0.026289  -0.024582        1.000000 -0.017445
# CPU_TDP                      0.018280   0.018433       -0.017445  1.000000
# GPU_Clock_Speed             -0.013674  -0.025523        0.029216 -0.014389
# GPU_Cores                    0.068844  -0.030932       -0.026146  0.043245
# GPU_Memory_Size              0.029448  -0.021305       -0.023424  0.004963
# GPU_Memory_Bandwidth         0.048416   0.021013        0.005313  0.017014
# Performance_Metric           0.019126  -0.005593        0.010177 -0.025565
#
#                       GPU_Clock_Speed  GPU_Cores  GPU_Memory_Size  \
# CPU_Clock_Speed             -0.013674   0.068844         0.029448
# CPU_Cores                   -0.025523  -0.030932        -0.021305
# CPU_Cache_Size               0.029216  -0.026146        -0.023424
# CPU_TDP                     -0.014389   0.043245         0.004963
# GPU_Clock_Speed              1.000000   0.021855         0.019795
# GPU_Cores                    0.021855   1.000000         0.056911
# GPU_Memory_Size              0.019795   0.056911         1.000000
# GPU_Memory_Bandwidth         0.006523  -0.009169        -0.003822
# Performance_Metric          -0.001664   0.012174         0.004930
#
#                       GPU_Memory_Bandwidth  Performance_Metric
# CPU_Clock_Speed                   0.048416            0.019126
# CPU_Cores                         0.021013           -0.005593
# CPU_Cache_Size                    0.005313            0.010177
# CPU_TDP                           0.017014           -0.025565
# GPU_Clock_Speed                   0.006523           -0.001664
# GPU_Cores                        -0.009169            0.012174
# GPU_Memory_Size                  -0.003822            0.004930
# GPU_Memory_Bandwidth              1.000000            0.047748
# Performance_Metric                0.047748            1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(train_data.corr(),annot=True,cmap="PuRd")
# Out:
# <Axes: >

# %%
sns.set()

plt.figure(figsize=(10, 4))
plt.title("PREDICTION CPU AND GPU COMBINATION PERFORMANCE SCORE")
plt.xlabel("Performance Score")
plt.ylabel("Frequency")
plt.hist(df["Performance_Metric"])
plt.show()

# %%
X_train = df[features].values
Y_train = df['Performance_Metric'].values

# %%
x_test
# Out:
#      CPU_Clock_Speed  CPU_Cores  CPU_Cache_Size  CPU_TDP  GPU_Clock_Speed  \
# 993              3.6         12              26      130             1357
# 859              3.0          4              11       49             1484
# 298              3.0          7              17       53             1928
# 553              2.9         10              25      121             1328
# 672              2.9          3              24       71             1184
# ..               ...        ...             ...      ...              ...
# 679              2.3          7               5      126             1700
# 722              2.4          4               7       58             1891
# 215              2.5          5              25      102             1788
# 653              2.0          5              12      138             1757
# 150              2.2          2              14      144             1312
#
#      GPU_Cores  GPU_Memory_Size  GPU_Memory_Bandwidth
# 993        302                7                   299
# 859        178                7                   101
# 298        320                7                   354
# 553        410                6                   104
# 672        472                2                   217
# ..         ...              ...                   ...
# 679        450                8                   358
# 722        440                9                   356
# 215        174                3                   350
# 653        294                3                   125
# 150        223                9                   198
#
# [200 rows x 8 columns]

# %%
y_test
# Out:
# array([1822,  955, 1059, 1918, 1329,  795, 1399,  759, 1658, 1712, 1790,
#        1305, 1084, 1136, 1597, 1107,  897,  774,  975, 1947, 1245, 1979,
#        1835, 1319,  800, 1681, 1279, 1699, 1803, 1367, 1634, 1752, 1111,
#         899, 1949,  829, 1140,  579, 1962, 1003, 1696,  586,  788, 1088,
#         878,  789, 1814, 1824, 1442, 1159, 1794,  632,  685,  782, 1952,
#        1309, 1066,  666,  974,  725, 1060,  779, 1303, 1438, 1256, 1696,
#         826, 1024,  974,  785, 1697,  611, 1024, 1355, 1167, 1623,  682,
#        1651, 1276, 1976,  859, 1169,  852, 1562,  903, 1219, 1954,  543,
#        1347,  799, 1656, 1932, 1544,  648, 1357, 1696,  551, 1875, 1050,
#        1874, 1570, 1642, 1536, 1984,  917,  705, 1276,  933, 1299, 1222,
#        1876,  908, 1510, 1158,  618, 1019,  691, 1689,  519,  986, 1923,
#        1149, 1161, 1416,  771, 1432,  986,  750, 1868,  533, 1997,  548,
#         868, 1399,  805,  712, 1846, 1587, 1864, 1211,  838, 1012, 1489,
#         656, 1911, 1229, 1818, 1052,  962, 1882,  504, 1665,  989, 1850,
#         789, 1981,  896,  554, 1387, 1926,  900, 1070, 1510,  747,  609,
#         743, 1997, 1336,  632, 1870,  701, 1607, 1958, 1765, 1761])

# %%
X_train
# Out:
# array([[  3.8,   7. ,  15. , ..., 481. ,   3. , 368. ],
#        [  2.7,  12. ,  28. , ..., 131. ,   7. , 148. ],
#        [  3.8,   7. ,  10. , ..., 439. ,   7. , 325. ],
#        ...,
#        [  4.1,   3. ,  32. , ..., 349. ,  10. , 147. ],
#        [  2.1,  11. ,  28. , ..., 287. ,   4. , 155. ],
#        [  3.7,   7. ,   5. , ..., 408. ,   7. , 193. ]])

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearnex.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# DecisionTreeRegressor

# %%
model1 = DecisionTreeRegressor()
model1.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict1 = model.predict(x_test)
# Out:
# /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
y_predict = model.predict(user_df)
# Out:
# /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
y_predict[0]
# Out:
# 1293.9519349857894

# %%
y_test[298]
# Out:
# 1327

# %%
y_predict2 = model1.predict(user_df)
y_predict1[0]
# Out:
# /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# 1229.8188105483628

# %%
plt.bar(range(4), y_predict[:10], width=0.2, label="LINEAR REGRESSION", color='red') #right sfted value by 2.0
plt.bar([i + 0.2 for i in range(4)], y_predict1[:4], width=0.2, label="DECISION TREE REGRESSOR", color='orange') #left shifted value by 2.0

plt.title("PREDICTION FOR CPU AND GPU COMBINATION PERFORMANCE")
plt.xlabel("FEQUENCY")
plt.ylabel("PERFORMANCE SCORE")
plt.legend(loc='upper right')
plt.ylim(0, 2500)
plt.show()

# %% [markdown]
# Visualization

# %%
plt.bar(range(4), y_predict[:10], width=0.2, label="PREDICTED VALUE", color='blue') #right sfted value by 2.0
plt.bar([i + 0.2 for i in range(4)], y_test[:4], width=0.2, label="ACTUAL VALUE", color='orange') #left shifted value by 2.0

plt.title("PREDICTION FOR CPU AND GPU COMBINATION PERFORMANCE")
plt.xlabel("FEQUENCY")
plt.ylabel("PERFORMANCE SCORE")
plt.legend(loc='upper right')
plt.ylim(0, 2500)
plt.show()

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual performance distribution
plt.hist(y, bins=10,color='blue', edgecolor='black',alpha=0.7, label='Actual Performance')

# Plot vertical line for mean of actual performance
plt.axvline(y.mean(), color='yellow', linestyle='dashed', linewidth=2, label='Mean Actual Performance')

# Plot predicted performance
plt.axvline(y_predict[0], color='red', linestyle='dashed', linewidth=2, label='Predicted Performance')

plt.xlabel('Performance Score')
plt.ylabel('Frequency')
plt.title('Distribution of Actual Performance with Predicted Performance')
plt.legend()
plt.show()

# %% [markdown]
# Predicted Performance Score

# %%
print(f"Predicted Performance Score: {y_predict[0]}")
# Out:
# Predicted Performance Score: 1293.9519349857894

# %%
# !pip install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (4.21.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.110.0)
# Requirement already satisfied: ffmpy in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.12.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: httpx>=0.24.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.21.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (5.12.0)
# Requirement already satisfied: jinja2<4.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (3.9.15)
# Requirement already satisfied: packaging in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (2.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (10.0.1)
# Requirement already satisfied: pydantic>=2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (2.6.3)
# Requirement already satisfied: pydub in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: semantic-version~=2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from gradio) (4.8.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio) (0.28.0)
# Requirement already satisfied: fsspec in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio-client==0.12.0->gradio) (2024.2.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from gradio-client==0.12.0->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio) (4.21.1)
# Requirement already satisfied: toolz in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (4.3.0)
# Requirement already satisfied: certifi in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: idna in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (2.16.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from fastapi->gradio) (0.36.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.17.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from anyio->httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.7)
# Requirement already satisfied: mdurl~=0.1 in /home/u0bba45b8bdf5f5458701693792db4a0/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import gradio as gr 

# Load dataset from CSV
df = pd.read_csv('data.csv')

# Linear Regression model
model = LinearRegression()
features = ['CPU_Clock_Speed', 'CPU_Cores', 'CPU_Cache_Size', 'CPU_TDP',
            'GPU_Clock_Speed', 'GPU_Cores', 'GPU_Memory_Size', 'GPU_Memory_Bandwidth']
X_train = df[features].values
Y_train = df['Performance_Metric'].values
model.fit(X_train, Y_train)

def predict_performance_metric(cpu_clock_speed, cpu_cores, cpu_cache_size, cpu_tdp, gpu_clock_speed, gpu_cores, gpu_memory_size, gpu_memory_bandwidth):
    input_features = np.array([[cpu_clock_speed, cpu_cores, cpu_cache_size, cpu_tdp, gpu_clock_speed, gpu_cores, gpu_memory_size, gpu_memory_bandwidth]])
    performance_metric = model.predict(input_features)
    return performance_metric
# Create input components
cpu_clock_speed = gr.components.Slider( label="CPU Clock Speed (GHz)")
cpu_cores = gr.components.Number(label="CPU Cores")
cpu_cache_size = gr.components.Number(label="CPU Cache Size (MB)")
cpu_tdp = gr.components.Number(label="CPU TDP (WATTS)")
gpu_clock_speed = gr.components.Number(label="GPU Clock Speed (MHz)")
gpu_cores = gr.components.Number(label="GPU Cores")
gpu_memory_size = gr.components.Number(label="GPU Memory Size (GB)")
gpu_memory_bandwidth = gr.components.Number(label="GPU Memory Bandwidth (GB/s)")

# Create output component
output = gr.components.Textbox(label="Predicted Performance Metric")

try:
    # Create Gradio interface with components
    interface = gr.Interface(fn=predict_performance_metric,
                             inputs=[cpu_clock_speed, cpu_cores, cpu_cache_size, cpu_tdp,
                                     gpu_clock_speed, gpu_cores, gpu_memory_size, gpu_memory_bandwidth],
                             outputs=output,
                             title="Performance Metric Predictor",
                             description="Enter CPU and GPU specifications to predict the Performance Metric.")
    # Launch the interface
    interface.launch()
except gr.InterfaceError as e:
    # Handle connection errors gracefully
    print("Connection error:", e)
    print("Please check your internet connection and try again.")
# Out:
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
